# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishu03/EpsilonPi/blob/main/GradientDescent_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
functionGradient = lambda x: 2*x*x

# %%
learningrate=0.01
precisionvar=0.000001
stepsize = 1
maxepoch = 1000
iterCounter = 0
currentX = 3
while stepsize > precisionvar and iterCounter < maxepoch:
  prev_x = currentX
  currentX = currentX - learningrate * functionGradient(prev_x)
  stepsize = abs(currentX - prev_x)
  iterCounter = iterCounter+1
  print("Iteration: {0},Value: {1}".format(iterCounter,currentX))
print("Minimum occurs at {0} & in the Iteration {1}".format(iterCounter,currentX))
# Out:
# Iteration: 1,Value: 2.82
# Iteration: 2,Value: 2.660952
# Iteration: 3,Value: 2.51933868907392
# Iteration: 4,Value: 2.392397340468626
# Iteration: 5,Value: 2.2779260397749987
# Iteration: 6,Value: 2.1741470989212988
# Iteration: 7,Value: 2.079608786766341
# Iteration: 8,Value: 1.9931133326464254
# Iteration: 9,Value: 1.9136633175109665
# Iteration: 10,Value: 1.840421171655225
# Iteration: 11,Value: 1.772678169873689
# Iteration: 12,Value: 1.7098304119947545
# Iteration: 13,Value: 1.6513600112391114
# Iteration: 14,Value: 1.5968202135047187
# Iteration: 15,Value: 1.5458235176195736
# Iteration: 16,Value: 1.4980321106670584
# Iteration: 17,Value: 1.4531501065752663
# Iteration: 18,Value: 1.410917201930472
# Iteration: 19,Value: 1.3711034549164058
# Iteration: 20,Value: 1.3335049612347318
# Iteration: 21,Value: 1.297940251601979
# Iteration: 22,Value: 1.2642472736674066
# Iteration: 23,Value: 1.2322808502878972
# Iteration: 24,Value: 1.201910528408172
# ...
